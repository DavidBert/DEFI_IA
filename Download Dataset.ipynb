# %% [markdown]
# ## Downloading the dataset from Kaggle competition

# %%
import kaggle
# !kaggle competitions download -c defi-ia-2022
# Out:
# ...
#   0%|          | 0.00/164M [00:00<?, ?B/s]
#   1%|          | 1.00M/164M [00:00<00:57, 2.95MB/s]
#   1%|          | 2.00M/164M [00:00<00:54, 3.10MB/s]
#   2%|▏         | 3.00M/164M [00:01<00:55, 3.04MB/s]
#   2%|▏         | 4.00M/164M [00:01<00:49, 3.37MB/s]
#   3%|▎         | 5.00M/164M [00:01<00:53, 3.14MB/s]
#   4%|▎         | 6.00M/164M [00:01<00:50, 3.28MB/s]
#   4%|▍         | 7.00M/164M [00:02<00:48, 3.42MB/s]
#   5%|▍         | 8.00M/164M [00:02<00:49, 3.31MB/s]
#   5%|▌         | 9.00M/164M [00:03<00:55, 2.95MB/s]
#   6%|▌         | 10.0M/164M [00:03<00:55, 2.92MB/s]
#   7%|▋         | 11.0M/164M [00:03<00:55, 2.90MB/s]
#   7%|▋         | 12.0M/164M [00:04<01:02, 2.55MB/s]
#   8%|▊         | 13.0M/164M [00:04<01:04, 2.47MB/s]
#   9%|▊         | 14.0M/164M [00:05<01:03, 2.49MB/s]
#   9%|▉         | 15.0M/164M [00:05<01:01, 2.54MB/s]
#  10%|▉         | 16.0M/164M [00:06<01:08, 2.28MB/s]
#  10%|█         | 17.0M/164M [00:06<01:08, 2.25MB/s]
# ...
